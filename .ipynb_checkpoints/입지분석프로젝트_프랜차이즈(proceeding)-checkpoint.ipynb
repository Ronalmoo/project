# %%
# %ls commercial_store/
# Out:
# 소상공인시장진흥공단_상가업소정보_201806_01.csv
# 소상공인시장진흥공단_상가업소정보_201806_02.csv
# 소상공인시장진흥공단_상가업소정보_201806_03.csv
# 소상공인시장진흥공단_상가업소정보_201806_04.csv

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from plotnine import *
import folium

# %%
shop_2018 = pd.read_csv('commercial_store/소상공인시장진흥공단_상가업소정보_201806_01.csv', encoding='cp949')
shop_2018.head()
# Out:
#      상가업소번호          상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 0  28523551  엘가커피부산아시아드점  부산아시아드점         Q       음식       Q12    커피점/카페
# 1  28498271    비비안아울렛중계점   아울렛중계점         D       소매       D05      의복의류
# 2  28512174  연세정신건강의학과의원      NaN         S       의료       S01        병원
# 3  28499926  독일지멘스보청기은평점      은평점         D       소매       D20  의약/의료품소매
# 4  28490321         서울모드      NaN         Q       음식       Q12    커피점/카페
#
#   상권업종소분류코드     상권업종소분류명 표준산업분류코드    ...                         건물관리번호  \
# 0    Q12A01  커피전문점/카페/다방   I56220    ...      2647010100111980000009422
# 1    D05A07     셔츠/내의/속옷      NaN    ...      1135010600105090000010511
# 2    S01B99         기타병원      NaN    ...      1111017400102990000005842
# 3    D20A02        보청기판매   G47812    ...      1138010300102810108040063
# 4    Q12A01  커피전문점/카페/다방   I56220    ...      1168010700105170027011767
#
#                건물명                  도로명주소   구우편번호    신우편번호  동정보 층정보  호정보  \
# 0  부산아시아드주경기장노외주차장     부산광역시 연제구 종합운동장로 7  611070  47500.0  NaN   1  NaN
# 1          2001아울렛  서울특별시 노원구 동일로204가길 46  139726   1783.0  NaN   3  NaN
# 2            유림문화사     서울특별시 종로구 종로 335-3  110540   3104.0  NaN   2  NaN
# 3              NaN      서울특별시 은평구 통일로 732  122040   3368.0  NaN   2  NaN
# 4             SM빌딩   서울특별시 강남구 도산대로11길 29  135888   6034.0  NaN   1  NaN
#
#            경도         위도
# 0  129.062034  35.191284
# 1  127.067888  37.641280
# 2  127.014500  37.573196
# 3  126.929871  37.610888
# 4  127.022212  37.519315
#
# [5 rows x 39 columns]

# %%
shop_2018.shape
# Out:
# (476183, 39)

# %%
# 커피 전문점 숫자(특정 업체, 브랜드명 검색)
coffee = shop_2018[shop_2018["상권업종소분류명"].str.contains('커피')]
coffee.shape
# Out:
# (18759, 39)

# %%
coffee.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
# 상호명으로 13472개가 있다.
coffee["상호명"].unique().shape
# Out:
# (13472,)

# %%
coffee['상호명'].value_counts()
# Out:
# 이디야커피              459
# 스타벅스               308
# 간단하지만특별한화피디Cafe    191
# 투썸플레이스             129
# 커피빈                125
# 엔제리너스              103
# 쥬씨                  93
# 할리스커피               92
# 탐앤탐스                85
# 빽다방                 84
# 카페베네                81
# 요거프레소               80
# 커피베이                78
# 공차                  72
# 커피에반하다              63
# 파스쿠찌                55
# 커피나무                53
# 쥬스식스                53
# 토프레소                47
# 컴포즈커피               42
# 더벤티                 40
# 커피마마                38
# 메가커피                37
# 설빙                  35
# 더카페                 31
# 할리스                 29
# 마리웨일237             28
# 셀렉토커피               25
# 더치앤빈                25
# 커피니                 24
#                   ...
# 디유케이커피               1
# 내찬기and카페             1
# 르돌치1946              1
# 몰카페                  1
# 존에프커피                1
# 쥬씨양재점                1
# 키미                   1
# 떼루와우면2호점             1
# 자문밖커피문               1
# 까페코어                 1
# ATwosomPlace         1
# 쥬뜨                   1
# 디앤드커피                1
# 프띠카페                 1
# 사랑채                  1
# 메가커피터미널점             1
# 커피야석촌점               1
# Main                 1
# 페이버릿스페셜티커피마켓         1
# 이송카페포차               1
# 아름뜰FOOD&COFFEE       1
# 슬로우제이커피로스팅웍스         1
# 쎄븐                   1
# 요고요고                 1
# 넬쿠오레델카페커피로스터즈        1
# 카페지로                 1
# 페가수스커피               1
# 카페예지                 1
# 와우카페                 1
# 대하                   1
# Name: 상호명, Length: 13472, dtype: int64

# %%
coffee.loc[coffee["상호명"] == '스타벅스', '상호명']
# Out:
# 12543     스타벅스
# 13302     스타벅스
# 31378     스타벅스
# 34199     스타벅스
# 34328     스타벅스
# 34354     스타벅스
# 35013     스타벅스
# 35237     스타벅스
# 39290     스타벅스
# 40083     스타벅스
# 40469     스타벅스
# 41603     스타벅스
# 41914     스타벅스
# 42502     스타벅스
# 42604     스타벅스
# 42955     스타벅스
# 43028     스타벅스
# 44123     스타벅스
# 44379     스타벅스
# 44449     스타벅스
# 44600     스타벅스
# 44814     스타벅스
# 45595     스타벅스
# 46006     스타벅스
# 46809     스타벅스
# 46976     스타벅스
# 47067     스타벅스
# 47275     스타벅스
# 48047     스타벅스
# 48945     스타벅스
#           ...
# 424246    스타벅스
# 427381    스타벅스
# 429539    스타벅스
# 430495    스타벅스
# 449443    스타벅스
# 450254    스타벅스
# 450987    스타벅스
# 451199    스타벅스
# 453458    스타벅스
# 453722    스타벅스
# 454874    스타벅스
# 456768    스타벅스
# 457490    스타벅스
# 457915    스타벅스
# 459330    스타벅스
# 460639    스타벅스
# 462406    스타벅스
# 462528    스타벅스
# 464852    스타벅스
# 465537    스타벅스
# 466414    스타벅스
# 468463    스타벅스
# 470132    스타벅스
# 470389    스타벅스
# 470523    스타벅스
# 472000    스타벅스
# 472654    스타벅스
# 472976    스타벅스
# 474313    스타벅스
# 474530    스타벅스
# Name: 상호명, Length: 308, dtype: object

#        '스타벅스서강광흥창역점', '스타벅스서울대역점', '스타벅스청담영동대로점', '스타벅스송파위례점',
#        '스타벅스연산시티타워점', '스타벅스문정하비오점', '스타벅스강남점', '스타벅스커피강남대로신사',
#        '스타벅스잠실대교남단점', '스타벅스자갈치역점', '스타벅스구로디지털타워점', '스타벅스동명대DT점',
#        '스타벅스강남오거리점', '스타벅스국제시장점', '스타벅스공릉역점', '스타벅스이수역사거리점', '스타벅스외대정문점',
#        '스타벅스노원마들역점', '스타벅스마곡나루역점', '스타벅스신대방삼거리역점', '스타벅스방화DT', '스타벅스신도림점',
#        '스타벅스역점', '스타벅스공덕'], dtype=object)

# %%
coffee['시도명'].isnull().sum()
# Out:
# 0

# %%
coffee['시도명'].unique()
# Out:
# array(['부산광역시', '서울특별시'], dtype=object)

# %%
coffee['시도명'].value_counts()
# Out:
# 서울특별시    14662
# 부산광역시     4097
# Name: 시도명, dtype: int64

# %%
coffee['시군구명'].unique()
# Out:
# array(['연제구', '강남구', '영등포구', '중구', '서초구', '성북구', '구로구', '종로구', '도봉구',
#        '마포구', '광진구', '기장군', '남구', '서대문구', '은평구', '양천구', '해운대구', '관악구',
#        '성동구', '송파구', '금천구', '사상구', '동대문구', '강서구', '금정구', '동작구', '중랑구',
#        '강동구', '사하구', '북구', '용산구', '노원구', '부산진구', '강북구', '수영구', '동구',
#        '동래구', '영도구', '서구'], dtype=object)

# %%
gangnam_and_seocho = coffee[(coffee['시군구명'] == '강남구') | (coffee['시군구명'] == '서초구')]

# %%
gangnam_and_seocho['시군구명'].unique()
# Out:
# array(['강남구', '서초구'], dtype=object)

# %%
coffee['상권업종중분류명'].value_counts()
# Out:
# 커피점/카페    18759
# Name: 상권업종중분류명, dtype: int64

# %%
(ggplot(shop_2018[:1000])
 + aes(x='경도', y= '위도')
 + geom_point()
 + theme(text=element_text(family='NanumGothicOTF'))
)
# Out:
# <ggplot: (315126013)>

# %%
shop_2018['시도명']
# Out:
# 0         부산광역시
# 1         서울특별시
# 2         서울특별시
# 3         서울특별시
# 4         서울특별시
# 5         부산광역시
# 6         부산광역시
# 7         부산광역시
# 8         서울특별시
# 9         서울특별시
# 10        서울특별시
# 11        부산광역시
# 12        서울특별시
# 13        서울특별시
# 14        서울특별시
# 15        서울특별시
# 16        부산광역시
# 17        서울특별시
# 18        서울특별시
# 19        서울특별시
# 20        서울특별시
# 21        부산광역시
# 22        서울특별시
# 23        서울특별시
# 24        서울특별시
# 25        서울특별시
# 26        서울특별시
# 27        서울특별시
# 28        서울특별시
# 29        서울특별시
#           ...
# 476153    서울특별시
# 476154    서울특별시
# 476155    서울특별시
# 476156    부산광역시
# 476157    서울특별시
# 476158    서울특별시
# 476159    서울특별시
# 476160    서울특별시
# 476161    서울특별시
# 476162    서울특별시
# 476163    서울특별시
# 476164    부산광역시
# 476165    부산광역시
# 476166    서울특별시
# 476167    서울특별시
# 476168    서울특별시
# 476169    서울특별시
# 476170    서울특별시
# 476171    서울특별시
# 476172    서울특별시
# 476173    서울특별시
# 476174    서울특별시
# 476175    서울특별시
# 476176    서울특별시
# 476177    부산광역시
# 476178    서울특별시
# 476179    서울특별시
# 476180    부산광역시
# 476181    부산광역시
# 476182    서울특별시
# Name: 시도명, Length: 476183, dtype: object

# %%
df_seoul = shop_2018.loc[shop_2018['시도명'].str.contains('서울')].copy()

# %%
df_seoul.shape
# Out:
# (330089, 39)

# %%
# 결측치 분석
df_seoul.isnull().sum()
# Out:
# 상가업소번호            0
# 상호명               0
# 지점명          285856
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드      19088
# 표준산업분류명       19088
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명              0
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지             0
# 지번부번지         62453
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             0
# 건물부번지        289290
# 건물관리번호            0
# 건물명          176500
# 도로명주소             0
# 구우편번호             0
# 신우편번호             2
# 동정보          305116
# 층정보           97585
# 호정보          283475
# 경도                0
# 위도                0
# dtype: int64

# %%
df_seoul['상권업종대분류명'].value_counts()
# Out:
# 음식          109766
# 소매          101297
# 생활서비스        52728
# 학문/교육        26294
# 의료           15144
# 부동산          12905
# 관광/여가/오락      9165
# 숙박            2744
# 스포츠             46
# Name: 상권업종대분류명, dtype: int64

# %%
df_seoul.describe(include=np.object)
# Out:
#            상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# count   330089  44233    330089   330089    330089   330089    330089
# unique  233567  15087         9        9        94       94       686
# top         CU     본점         Q       음식       Q01       한식    Q01A01
# freq      1450    294    109766   109766     35778    35778     23721
#
#          상권업종소분류명 표준산업분류코드  표준산업분류명  ...      법정동명   대지구분명  \
# count      330089   311001   311001  ...    330089  330089
# unique        686      210      210  ...       465       2
# top     한식/백반/한정식   I56111  한식 음식점업  ...       신림동      대지
# freq        23721    43878    43878  ...      6759  329735
#
#                         지번주소           도로명                     건물관리번호  \
# count                 330089        330089                     330089
# unique                124181         11861                     124735
# top     서울특별시 종로구 종로6가 262-1  서울특별시 종로구 종로  1111016400102700003012054
# freq                     976          2352                       1008
#
#             건물명             도로명주소    동정보     층정보    호정보
# count    153589            330089  24973  232504  46614
# unique    25179            123973    914     115   2494
# top     동대문종합시장  서울특별시 종로구 종로 266      1       1      1
# freq       1011               995   4307  161124   5469
#
# [4 rows x 23 columns]

# %%
df_seoul[['위도', '경도']].describe()
# mean 평균값은 지도의 중앙값을 불러온다.
# max는 지도의 가장 윗부분
# min은 지도의 가장 아랫 부분
# Out:
#                   위도             경도
# count  330089.000000  330089.000000
# mean       37.545992     126.994943
# std         0.049406       0.081294
# min        37.434081     126.768169
# 25%        37.505306     126.925013
# 50%        37.543243     127.009046
# 75%        37.574720     127.055651
# max        37.692398     127.182588

# %%
(ggplot(df_seoul)
 + aes('상권업종대분류명')
 + geom_bar(fill='#8181F7')
 + ggtitle('상권업종대분류명')
 + coord_flip()
 + theme(text=element_text(family="NanumGothicOTF"),
        axis_text_x=element_text(rotation=60))
)
# Out:
# <ggplot: (330799154)>

# %%
df_food = df_seoul.loc[df_seoul['상권업종대분류명'].str.contains('음식')]
df_food.shape
# Out:
# (109766, 39)

# %%
(ggplot(df_food)
 + aes('상권업종중분류명')
 + geom_bar(fill='#FF6666')
 + ggtitle('상권업종중분류명')
 + coord_flip()
 + theme(text=element_text(family='NanumGothicOTF'),
         axis_text_x=element_text(rotation=60))
)
# Out:
# <ggplot: (-9223372036539627271)>

# %%
df_fast_food = df_food.loc[df_food['상권업종중분류명'] == '패스트푸드']
df_fast_food.shape
# Out:
# (4605, 39)

# %%
df_food.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df_fast_food['상호명'].unique()
# Out:
# array(['피자마루', '롯데리아', '배스킨라빈스', ..., '브리웰', '베이크럽', '델리'], dtype=object)

# %%
df_fast_food['상호명'].unique().shape
# Out:
# (2747,)

# %% [markdown]
# # 베스킨라빈스와 던킨도너츠와 입지분석

# %%
df_31 = df_seoul.loc[df_seoul['상호명'].str.contains('베스킨라|배스킨라|던킨')].copy()
df_31['상호명'].unique(), df_31.shape
# Out:
# (array(['배스킨라빈스', '던킨도너츠테크노마트점', '던킨도너츠창동하나로', '던킨도너츠용산민자역사2호', '베스킨라빈슨',
#         '던킨도너츠', '베스킨라빈스은행나무점', '베스킨라빈스', '코레일유통던킨도너츠점', '던킨도너츠교대점',
#         '던킨도너츠건대영존점', '베스킨라빈스마들역점', '베스킨라빈스쌍문점', '코레일유통커피앤던킨도너츠',
#         '배스킨라빈스강남중앙', '배스킨라빈스31', '베스킨라빈스31홈플러스시흥점', '베스킨라빈스목동2단지점',
#         '던킨도너츠성신여대점', '베스킨라빈스한성대역점', '배스킨라빈스청량리역사점', '베스킨라빈스신도림테크노마트',
#         '베스킨라빈스아이스크림', '베스킨라빈스미아역점', '배스킨라빈스31성내역점', '비알코리아베스킨라빈스',
#         '비알코리아던킨도너츠목동', '비알코리아베스킨라빈스양', '비알코리아던킨도너츠서울', '비알코리아던킨도너츠건대',
#         '던킨도너츠광운대역', '던킨도너츠도곡', '던킨도너츠노원세이브존', '던킨도너츠아이비케이', '베스킨라빈스중곡역',
#         '던킨도너츠공항철도서울역사', '베스킨라빈스송파', '배스킨라빈스용산후암', '던킨도너츠동대문홈플러스',
#         '베스킨라빈스신림포도몰', '배스킨라빈스신창', '배스킨라빈스영등포문래', '던킨도너츠용산센트럴점',
#         '던킨커피포워드강남스퀘어', '던킨도너츠김포공항국내선', '비알코리아던킨도너츠강남스퀘어',
#         '배스킨라빈스31남부터미널역점', '배스킨라빈스31신풍역점', '배스킨라빈스청춘2017커피페스티벌부스',
#         '배스킨라빈스31BROWN청담점', '베스킨라빈스동대문'], dtype=object), (522, 39))

# %% [markdown]
# ## 사용할 컬럼 선정하기

# %%
df_31.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df_31 = df_31[['상호명', '지점명', '상권업종대분류명', '상권업종중분류명',
               '상권업종소분류명', '지번주소', '도로명주소', '위도', '경도', '시군구명', '행정동명']].copy()
df_31.head()
# Out:
#                 상호명      지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명  \
# 63           배스킨라빈스    관악구청점       음식    패스트푸드  아이스크림판매
# 1564    던킨도너츠테크노마트점   테크노마트점       음식    패스트푸드    도너츠전문
# 1921     던킨도너츠창동하나로      NaN       음식    패스트푸드    도너츠전문
# 1958  던킨도너츠용산민자역사2호      NaN       음식    패스트푸드    도너츠전문
# 2194         베스킨라빈슨  잠실롯데캐슬점       음식    패스트푸드  아이스크림판매
#
#                         지번주소                 도로명주소         위도          경도  \
# 63      서울특별시 관악구 봉천동 863-13     서울특별시 관악구 관악로 161  37.479599  126.952166
# 1564     서울특별시 광진구 구의동 546-4  서울특별시 광진구 광나루로56길 85  37.535713  127.095681
# 1921       서울특별시 도봉구 창동 1-10   서울특별시 도봉구 마들로11길 20  37.655101  127.050818
# 1958  서울특별시 용산구 한강로3가 40-999  서울특별시 용산구 한강대로21나길 7  37.527903  126.963223
# 2194      서울특별시 송파구 신천동 7-18    서울특별시 송파구 올림픽로 269  37.514369  127.100565
#
#      시군구명  행정동명
# 63    관악구   청룡동
# 1564  광진구  구의3동
# 1921  도봉구   창4동
# 1958  용산구  한강로동
# 2194  송파구  잠실6동

# %%
df_31['상호명'].value_counts()
# Out:
# 배스킨라빈스31             102
# 던킨도너츠                 86
# 베스킨라빈스                56
# 배스킨라빈스                44
# 던킨도넛                   4
# 베스킨라빈스아이스크림            2
# 배스킨라빈스31성수이마트점         1
# 던킨도너츠강남역점              1
# 배스킨라빈스31위례중앙점          1
# 베스킨라빈스동대문              1
# 배스킨라빈스31응암점            1
# 던킨도너츠홍대점               1
# 배스킨라빈스31굽은다리역점         1
# 베스킨라빈슨                 1
# 배스킨라빈스31영등포문래점         1
# 배스킨라빈스31북가좌점           1
# 배스킨라빈스31남구로점           1
# 베스킨라빈스장안점              1
# 배스킨라빈스31천호로데오점         1
# 배스킨라빈스31서초점            1
# 배스킨라빈스브라운청담점           1
# 베스킨라빈스삼전점              1
# 던킨도너츠공릉역점              1
# 배스킨라빈스31쌍문점            1
# 배스킨라빈스31영등포구청점         1
# 배스킨라빈스31방학역점           1
# 배스킨라빈스31금천홈플러스점        1
# 던킨도너츠시청역               1
# 던킨&아트샵                 1
# 비알코리아던킨도너츠서여           1
#                     ...
# 베스킨라빈스성수역점             1
# 베스킨라빈스은행나무점            1
# 배스킨라빈스31개봉중앙점          1
# 배스킨라빈스31구로오류동          1
# 배스킨라빈스31구일역점           1
# 배스킨라빈스31CAFE31신촌점      1
# 배스킨라빈스31대학로점           1
# 배스킨라빈스31명동1호점          1
# 던킨도너츠아이비케이             1
# 배스킨라빈스31홍대상상마당점        1
# 던킨도너츠구로태평양물산점          1
# 배스킨라빈스31구의역점           1
# 배스킨라빈스동대문홈플러스          1
# 배스킨라빈스31은평뉴타운점         1
# 던킨도너츠김포국제공항점           1
# 베스킨라빈스상왕십리센트라스점        1
# 배스킨라빈스31방화동점           1
# 베스킨라빈스신도림테크노마트         1
# 배스킨라빈스31건대역점           1
# 배스킨라빈스31상암홈플러스점        1
# 던킨도너츠합정역사점             1
# 배스킨라빈스31마포용강점          1
# 비알코리아던킨도너츠두산           1
# 던킨도너츠김포공항국내선           1
# 배스킨라빈스31구로구청점          1
# 배스킨라빈스31장승배기역점         1
# 비알코리아던킨도너츠고대           1
# 베스킨라빈스남부터미널역점          1
# 배스킨라빈스31청담2호점          1
# 던킨도너츠방화역점              1
# Name: 상호명, Length: 234, dtype: int64

# %%
df_31['브랜드명'] = ''

# %%
df_31[['상호명', '브랜드명']].head()
# Out:
#                 상호명 브랜드명
# 63           배스킨라빈스
# 1564    던킨도너츠테크노마트점
# 1921     던킨도너츠창동하나로
# 1958  던킨도너츠용산민자역사2호
# 2194         베스킨라빈슨

# %%
df_31.loc[df_31['상호명'].str.contains('베스킨|배스킨'), '브랜드명'] = '베스킨라빈스'
df_31.loc[df_31['상호명'].str.contains('던킨'), '브랜드명'] = '던킨도너츠'

# %%
 df_31.head()
# Out:
#                 상호명      지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명  \
# 63           배스킨라빈스    관악구청점       음식    패스트푸드  아이스크림판매
# 1564    던킨도너츠테크노마트점   테크노마트점       음식    패스트푸드    도너츠전문
# 456273                 던킨도너츠   던킨도너츠
# 460241                 던킨도너츠   던킨도너츠
# 463277          던킨도너츠김포공항국내선   던킨도너츠
# 464632              배스킨라빈스31  베스킨라빈스
# 465155                배스킨라빈스  베스킨라빈스
# 465315       비알코리아던킨도너츠강남스퀘어   던킨도너츠
# 465665              배스킨라빈스31  베스킨라빈스
# 465723              배스킨라빈스31  베스킨라빈스
# 467788       배스킨라빈스31남부터미널역점  베스킨라빈스
# 468502          배스킨라빈스31신풍역점  베스킨라빈스
# 468649  배스킨라빈스청춘2017커피페스티벌부스  베스킨라빈스
# 469145      배스킨라빈스31BROWN청담점  베스킨라빈스
# 469891             베스킨라빈스동대문  베스킨라빈스
# 470753              배스킨라빈스31  베스킨라빈스
# 470770              배스킨라빈스31  베스킨라빈스
# 470975              배스킨라빈스31  베스킨라빈스
# 471432              배스킨라빈스31  베스킨라빈스
# 471726              배스킨라빈스31  베스킨라빈스
# 473536              배스킨라빈스31  베스킨라빈스
# 473554              배스킨라빈스31  베스킨라빈스
# 474002                 던킨도너츠   던킨도너츠
# 475841              배스킨라빈스31  베스킨라빈스
# 475842              배스킨라빈스31  베스킨라빈스
# 476000                 던킨도너츠   던킨도너츠
#
# [522 rows x 2 columns]

# %%
df_31_group_count = df_31['브랜드명'].value_counts()
df_31_group_count
# Out:
# 베스킨라빈스    374
# 던킨도너츠     148
# Name: 브랜드명, dtype: int64

# %%
# 베스킨라빈스가 던킨 도너츠보다 2.5배 많다.
df_31_group_count[0] / df_31_group_count[1]
# Out:
# 2.527027027027027

# %%
df_31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 63 to 476000
# Data columns (total 12 columns):
# 상호명         522 non-null object
# 지점명         408 non-null object
# 상권업종대분류명    522 non-null object
# 상권업종중분류명    522 non-null object
# 상권업종소분류명    522 non-null object
# 지번주소        522 non-null object
# 도로명주소       522 non-null object
# 위도          522 non-null float64
# 경도          522 non-null float64
# 시군구명        522 non-null object
# 행정동명        522 non-null object
# 브랜드명        522 non-null object
# dtypes: float64(2), object(10)
# memory usage: 53.0+ KB

# %%
df_31['위도'] = df_31['위도'].astype(float)
df_31['경도'] = df_31['경도'].astype(float)

# %%
(ggplot(df_31)
 + aes(x='경도', y='위도', color='브랜드명')
 + geom_point()
 + theme(text=element_text(family='NanumGothicOTF'))
 + scale_fill_gradient2(low = 'blue', high = 'green')
)
# Out:
# <ggplot: (-9223372036524666066)>

# %%
# folium?

# %%
geo_df = df_31.copy()


def draw_marker():
    map = folium.Map(location=[geo_df['위도'].mean(), geo_df['경도'].mean()], zoom_start=12)
    for n in geo_df.index:
        popup_name = geo_df['브랜드명'][n] + ' - ' + geo_df['도로명주소'][n]
        if geo_df['브랜드명'][n] == '던킨도너츠':
            icon_color = 'pink'
        else:
            icon_color = 'blue'
        
        folium.Marker([geo_df['위도'][n], geo_df['경도'][n]],
                     popup=popup_name,
                     icon=folium.Icon(color=icon_color)).add_to(map)
    return map

# %%
draw_marker()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
