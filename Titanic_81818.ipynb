# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv("train.csv", index_col="PassengerId")
train.shape
# Out:
# (891, 11)

# %%
train.head()
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test = pd.read_csv("test.csv", index_col="PassengerId")

# %%
test.head(), test.shape
# Out:
# (             Pclass                                          Name     Sex  \
#  PassengerId
#  892               3                              Kelly, Mr. James    male
#  893               3              Wilkes, Mrs. James (Ellen Needs)  female
#  894               2                     Myles, Mr. Thomas Francis    male
#  895               3                              Wirz, Mr. Albert    male
#  896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#                Age  SibSp  Parch   Ticket     Fare Cabin Embarked
#  PassengerId
#  892          34.5      0      0   330911   7.8292   NaN        Q
#  893          47.0      1      0   363272   7.0000   NaN        S
#  894          62.0      0      0   240276   9.6875   NaN        Q
#  895          27.0      0      0   315154   8.6625   NaN        S
#  896          22.0      1      1  3101298  12.2875   NaN        S  , (418, 10))

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
train[["Age"]].describe()
# Out:
#               Age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %% [markdown]
# # Sex

# %%
sns.countplot(data=train, x="Sex", hue="Survived")

# %%
pd.pivot_table(data=train, index="Sex", values="Survived")
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
0.742038 / 0.188908
# Out:
# 3.928039045461283

# %% [markdown]
# female이 약 3.9배 생존률이 높다.

# %% [markdown]
# # Pclass

# %%
sns.countplot(data=train, x="Pclass", hue="Survived")

# %%
pd.pivot_table(train, index="Pclass", values="Survived")
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# Pclass(좌석 등급)가 높을수록 생존률이 높아진다.

# %% [markdown]
# # Embarked

# %%
sns.countplot(data=train, x="Embarked", hue="Survived")

# %%
pd.pivot_table(train, index="Embarked", values="Survived")
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
sns.countplot(data=train, x="Parch", hue="Survived")

# %% [markdown]
# # Age & Fare

# %%
sns.lmplot(data=train, x="Age", y="Fare", hue="Survived", fit_reg=False)

# %% [markdown]
# # Outlier 제거

# %%
low_fare = train[train["Fare"] < 500]
train.shape, low_fare.shape
# Out:
# ((891, 11), (888, 11))

# %%
sns.lmplot(data=low_fare, x="Age", y="Fare", hue="Survived", fit_reg=False)

# %%
low_low_fare = train[train["Fare"] < 100]

train.shape, low_low_fare.shape
# Out:
# ((891, 11), (838, 11))

# %%
sns.lmplot(data=low_low_fare, x="Age", y="Fare", hue="Survived", fit_reg=False)

# %% [markdown]
# # SibSp, Parch

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
print(train.shape)

train[["SibSp", "Parch", "FamilySize"]].head()
# Out:
# (891, 12)
#              SibSp  Parch  FamilySize
# PassengerId
# 1                1      0           2
# 2                1      0           2
# 3                0      0           1
# 4                1      0           2
# 5                0      0           1

# %%
sns.countplot(data=train, x="FamilySize", hue="Survived")

# %%
train.loc[train["FamilySize"] == 1, "FamilyType"] = "Single"
train.loc[(train["FamilySize"] >= 2) & (train["FamilySize"] < 5), "FamilyType"] = "Nuclear"
train.loc[train["FamilySize"] >= 5, "FamilyType"] = "Big"

print(train.shape)

train[["FamilySize", "FamilyType"]].head(10)
# Out:
# (891, 13)
#              FamilySize FamilyType
# PassengerId
# 1                     2    Nuclear
# 2                     2    Nuclear
# 3                     1     Single
# 4                     2    Nuclear
# 5                     1     Single
# 6                     1     Single
# 7                     1     Single
# 8                     5        Big
# 9                     3    Nuclear
# 10                    2    Nuclear

# %%
sns.countplot(data=train, x="FamilyType", hue="Survived")

# %%
pd.pivot_table(data=train, index="FamilyType", values="Survived")
# Out:
#             Survived
# FamilyType
# Big         0.161290
# Nuclear     0.578767
# Single      0.303538

# %%
train[["FamilyType"]].describe()
# Out:
#        FamilyType
# count         891
# unique          3
# top        Single
# freq          537

# %% [markdown]
# # Name

# %%
train[["Name"]].head(10)
# Out:
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# 6                                             Moran, Mr. James
# 7                                      McCarthy, Mr. Timothy J
# 8                               Palsson, Master. Gosta Leonard
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                         Nasser, Mrs. Nicholas (Adele Achem)

# %%
def get_title(name):
    return name.split(", ")[1].split(". ")[0]

# %%
train["Name"].apply(get_title).unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
train.loc[train["Name"].str.contains("Mr"), "Title"] = "Mr"
train.loc[train["Name"].str.contains("Mrs"), "Title"] = "Mrs"
train.loc[train["Name"].str.contains("Miss"), "Title"] = "Miss"
train.loc[train["Name"].str.contains("Master"), "Title"] = "Master"

# %%
train[["Name", "Title"]].head(50)
# Out:
#                                                           Name   Title
# PassengerId
# 1                                      Braund, Mr. Owen Harris      Mr
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...     Mrs
# 3                                       Heikkinen, Miss. Laina    Miss
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)     Mrs
# 5                                     Allen, Mr. William Henry      Mr
# 6                                             Moran, Mr. James      Mr
# 7                                      McCarthy, Mr. Timothy J      Mr
# 8                               Palsson, Master. Gosta Leonard  Master
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     Mrs
# 10                         Nasser, Mrs. Nicholas (Adele Achem)     Mrs
# 11                             Sandstrom, Miss. Marguerite Rut    Miss
# 12                                    Bonnell, Miss. Elizabeth    Miss
# 13                              Saundercock, Mr. William Henry      Mr
# 14                                 Andersson, Mr. Anders Johan      Mr
# 15                        Vestrom, Miss. Hulda Amanda Adolfina    Miss
# 16                            Hewlett, Mrs. (Mary D Kingcome)      Mrs
# 17                                        Rice, Master. Eugene  Master
# 18                                Williams, Mr. Charles Eugene      Mr
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...     Mrs
# 20                                     Masselmani, Mrs. Fatima     Mrs
# 21                                        Fynney, Mr. Joseph J      Mr
# 22                                       Beesley, Mr. Lawrence      Mr
# 23                                 McGowan, Miss. Anna "Annie"    Miss
# 24                                Sloper, Mr. William Thompson      Mr
# 25                               Palsson, Miss. Torborg Danira    Miss
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...     Mrs
# 27                                     Emir, Mr. Farred Chehab      Mr
# 28                              Fortune, Mr. Charles Alexander      Mr
# 29                               O'Dwyer, Miss. Ellen "Nellie"    Miss
# 30                                         Todoroff, Mr. Lalio      Mr
# 31                                    Uruchurtu, Don. Manuel E     NaN
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)     Mrs
# 33                                    Glynn, Miss. Mary Agatha    Miss
# 34                                       Wheadon, Mr. Edward H      Mr
# 35                                     Meyer, Mr. Edgar Joseph      Mr
# 36                              Holverson, Mr. Alexander Oskar      Mr
# 37                                            Mamee, Mr. Hanna      Mr
# 38                                    Cann, Mr. Ernest Charles      Mr
# 39                          Vander Planke, Miss. Augusta Maria    Miss
# 40                                 Nicola-Yarred, Miss. Jamila    Miss
# 41              Ahlin, Mrs. Johan (Johanna Persdotter Larsson)     Mrs
# 42           Turpin, Mrs. William John Robert (Dorothy Ann ...     Mrs
# 43                                         Kraeff, Mr. Theodor      Mr
# 44                    Laroche, Miss. Simonne Marie Anne Andree    Miss
# 45                               Devaney, Miss. Margaret Delia    Miss
# 46                                    Rogers, Mr. William John      Mr
# 47                                           Lennon, Mr. Denis      Mr
# 48                                   O'Driscoll, Miss. Bridget    Miss
# 49                                         Samaan, Mr. Youssef      Mr
# 50               Arnold-Franchi, Mrs. Josef (Josefine Franchi)     Mrs

# %%
sns.countplot(data=train, x='Title', hue="Survived")

# %% [markdown]
# 여성이 생존률이 높다.

# %%
pd.pivot_table(data=train, index="Title", values="Survived")
# Out:
#         Survived
# Title
# Master  0.575000
# Miss    0.697802
# Mr      0.158301
# Mrs     0.795276

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Encode Sex

# %%
train.loc[train["Sex"] == "male", "Sex_encode"] = 0
train.loc[train["Sex"] == "female", "Sex_encode"] = 1

print(train.shape)
train[["Sex", "Sex_encode"]].head()
# Out:
# (891, 15)
#                 Sex  Sex_encode
# PassengerId
# 1              male         0.0
# 2            female         1.0
# 3            female         1.0
# 4            female         1.0
# 5              male         0.0

# %%
test.loc[test["Sex"] == "male", "Sex_encode"] = 0
test.loc[test["Sex"] == "female", "Sex_encode"] = 1

print(test.shape)
test[["Sex", "Sex_encode"]].head()
# Out:
# (418, 11)
#                 Sex  Sex_encode
# PassengerId
# 892            male         0.0
# 893          female         1.0
# 894            male         0.0
# 895            male         0.0
# 896          female         1.0

# %% [markdown]
# ## Fill in missing fare

# %%
train[train["Fare"].isnull()] # train "fare" 컬럼에는 Nan값이 없다.
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, FamilySize, FamilyType, Title, Sex_encode]
# Index: []

# %%
test[test["Fare"].isnull()] # test에는 한 건
# Out:
#              Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# PassengerId
# 1044              3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#              Fare Cabin Embarked  Sex_encode
# PassengerId
# 1044          NaN   NaN        S         0.0

# %%
train["Fare_fillin"] = train["Fare"]
print(train.shape)
train[["Fare", "Fare_fillin"]].head()
# Out:
# (891, 16)
#                 Fare  Fare_fillin
# PassengerId
# 1             7.2500       7.2500
# 2            71.2833      71.2833
# 3             7.9250       7.9250
# 4            53.1000      53.1000
# 5             8.0500       8.0500

# %%
test["Fare_fillin"] = test["Fare"]
print(test.shape)
test[["Fare", "Fare_fillin"]].head()
# Out:
# (418, 12)
#                 Fare  Fare_fillin
# PassengerId
# 892           7.8292       7.8292
# 893           7.0000       7.0000
# 894           9.6875       9.6875
# 895           8.6625       8.6625
# 896          12.2875      12.2875

# %%
test.loc[test["Fare"].isnull(), "Fare_fillin"] = 0
test.loc[test["Fare"].isnull(), ["Fare", "Fare_fillin"]]
# Out:
#              Fare  Fare_fillin
# PassengerId
# 1044          NaN          0.0

# %% [markdown]
# # Encode Embark

# %%
train["Embarked_C"] = train["Embarked"] == "C"
train["Embarked_S"] = train["Embarked"] == "S"
train["Embarked_Q"] = train["Embarked"] == "Q"
train[["Embarked", "Embarked_C", "Embarked_S", "Embarked_Q"]].head()
# Out:
#             Embarked  Embarked_C  Embarked_S  Embarked_Q
# PassengerId
# 1                  S       False        True       False
# 2                  C        True       False       False
# 3                  S       False        True       False
# 4                  S       False        True       False
# 5                  S       False        True       False

# %%
test["Embarked_C"] = test["Embarked"] == "C"
test["Embarked_S"] = test["Embarked"] == "S"
test["Embarked_Q"] = test["Embarked"] == "Q"
test[["Embarked", "Embarked_C", "Embarked_S", "Embarked_Q"]].head()
# Out:
#             Embarked  Embarked_C  Embarked_S  Embarked_Q
# PassengerId
# 892                Q       False       False        True
# 893                S       False        True       False
# 894                Q       False       False        True
# 895                S       False        True       False
# 896                S       False        True       False

# %% [markdown]
# # Age

# %%
train["Child"] = train["Age"] < 15
print(train.shape)
train[["Age", "Child"]].head(10)
# Out:
# (891, 20)
#               Age  Child
# PassengerId
# 1            22.0  False
# 2            38.0  False
# 3            26.0  False
# 4            35.0  False
# 5            35.0  False
# 6             NaN  False
# 7            54.0  False
# 8             2.0   True
# 9            27.0  False
# 10           14.0   True

# %%
test["Child"] = test["Age"] < 15
print(test.shape)
test[["Age", "Child"]].head(10)
# Out:
# (418, 16)
#               Age  Child
# PassengerId
# 892          34.5  False
# 893          47.0  False
# 894          62.0  False
# 895          27.0  False
# 896          22.0  False
# 897          14.0   True
# 898          30.0  False
# 899          26.0  False
# 900          18.0  False
# 901          21.0  False

# %% [markdown]
# # FamilySize

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
print(train.shape)
train[["SibSp", "Parch", "FamilySize"]].head()
# Out:
# (891, 20)
#              SibSp  Parch  FamilySize
# PassengerId
# 1                1      0           2
# 2                1      0           2
# 3                0      0           1
# 4                1      0           2
# 5                0      0           1

# %%
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1
print(test.shape)
test[["SibSp", "Parch", "FamilySize"]].head()
# Out:
# (418, 17)
#              SibSp  Parch  FamilySize
# PassengerId
# 892              0      0           1
# 893              1      0           2
# 894              0      0           1
# 895              0      0           1
# 896              1      1           3

# %%
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1
print(test.shape)
test[["SibSp", "Parch", "FamilySize"]].head()
# Out:
# (418, 17)
#              SibSp  Parch  FamilySize
# PassengerId
# 892              0      0           1
# 893              1      0           2
# 894              0      0           1
# 895              0      0           1
# 896              1      1           3

# %%
# 가족
train["Single"] = train["FamilySize"] == 1
train["Nuclear"] = (train["FamilySize"] > 1) & ( train["FamilySize"] < 5)
train["Big"] = train["FamilySize"] >= 5
print(train.shape)
train[["FamilySize", "Single", "Nuclear", "Big"]].head(10)
# Out:
# (891, 23)
#              FamilySize  Single  Nuclear    Big
# PassengerId
# 1                     2   False     True  False
# 2                     2   False     True  False
# 3                     1    True    False  False
# 4                     2   False     True  False
# 5                     1    True    False  False
# 6                     1    True    False  False
# 7                     1    True    False  False
# 8                     5   False    False   True
# 9                     3   False     True  False
# 10                    2   False     True  False

# %%
# train 데이터를 다룬 것과 마찬가지로,
# test 데이터에도 FamilySize를 활용하여 Single, Nuclear, Big 컬럼을 새로 만듭니다.
test["Single"] = test["FamilySize"] == 1
test["Nuclear"] = (test["FamilySize"] > 1) & (test["FamilySize"] < 5)
test["Big"] = test["FamilySize"] >= 5

# test 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(test.shape)

# test 데이터의 상위 10개를 띄우되, FamilySize, Single, Nuclear, Big 컬럼만 출력합니다.
test[["FamilySize", "Single", "Nuclear", "Big"]].head(10)
# Out:
# (418, 20)
#              FamilySize  Single  Nuclear    Big
# PassengerId
# 892                   1    True    False  False
# 893                   2   False     True  False
# 894                   1    True    False  False
# 895                   1    True    False  False
# 896                   3   False     True  False
# 897                   1    True    False  False
# 898                   1    True    False  False
# 899                   3   False     True  False
# 900                   1    True    False  False
# 901                   3   False     True  False

# %%
train["Master"] = train["Name"].str.contains("Master")

# train 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(train.shape)

# train 데이터의 상위 10개를 띄우되, Name, Master 컬럼만 출력합니다.
train[["Name", "Master"]].head(10)
# Out:
# (891, 24)
#                                                           Name  Master
# PassengerId
# 1                                      Braund, Mr. Owen Harris   False
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   False
# 3                                       Heikkinen, Miss. Laina   False
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   False
# 5                                     Allen, Mr. William Henry   False
# 6                                             Moran, Mr. James   False
# 7                                      McCarthy, Mr. Timothy J   False
# 8                               Palsson, Master. Gosta Leonard    True
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   False
# 10                         Nasser, Mrs. Nicholas (Adele Achem)   False

# %%
test["Master"] = test["Name"].str.contains("Master")

# test 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(test.shape)

# train 데이터의 상위 10개를 띄우되, Name, Master 컬럼만 출력합니다.
test[["Name", "Master"]].head(10)
# Out:
# (418, 21)
#                                                      Name  Master
# PassengerId
# 892                                      Kelly, Mr. James   False
# 893                      Wilkes, Mrs. James (Ellen Needs)   False
# 894                             Myles, Mr. Thomas Francis   False
# 895                                      Wirz, Mr. Albert   False
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)   False
# 897                            Svensson, Mr. Johan Cervin   False
# 898                                  Connolly, Miss. Kate   False
# 899                          Caldwell, Mr. Albert Francis   False
# 900             Abrahim, Mrs. Joseph (Sophie Halaut Easu)   False
# 901                               Davies, Mr. John Samuel   False

# %%
feature_names = ["Pclass", "Sex_encode", "Fare_fillin", "Embarked_C", "Embarked_S", "Embarked_Q", "Child", "Single", "Nuclear", "Big", "Master"]
feature_names
# Out:
# ['Pclass',
#  'Sex_encode',
#  'Fare_fillin',
#  'Embarked_C',
#  'Embarked_S',
#  'Embarked_Q',
#  'Child',
#  'Single',
#  'Nuclear',
#  'Big',
#  'Master']

# %%
label_name ="Survived"
label_name
# Out:
# 'Survived'

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (891, 11)
#              Pclass  Sex_encode  Fare_fillin  Embarked_C  Embarked_S  \
# PassengerId
# 1                 3         0.0       7.2500       False        True
# 2                 1         1.0      71.2833        True       False
# 3                 3         1.0       7.9250       False        True
# 4                 1         1.0      53.1000       False        True
# 5                 3         0.0       8.0500       False        True
#
#              Embarked_Q  Child  Single  Nuclear    Big  Master
# PassengerId
# 1                 False  False   False     True  False   False
# 2                 False  False   False     True  False   False
# 3                 False  False    True    False  False   False
# 4                 False  False   False     True  False   False
# 5                 False  False    True    False  False   False

# %%
X_test = test[feature_names]

# X_test 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(X_test.shape)

# X_test 데이터의 상위 5개를 띄웁니다.
X_test.head()
# Out:
# (418, 11)
#              Pclass  Sex_encode  Fare_fillin  Embarked_C  Embarked_S  \
# PassengerId
# 892               3         0.0       7.8292       False       False
# 893               3         1.0       7.0000       False        True
# 894               2         0.0       9.6875       False       False
# 895               3         0.0       8.6625       False        True
# 896               3         1.0      12.2875       False        True
#
#              Embarked_Q  Child  Single  Nuclear    Big  Master
# PassengerId
# 892                True  False    True    False  False   False
# 893               False  False   False     True  False   False
# 894                True  False    True    False  False   False
# 895               False  False    True    False  False   False
# 896               False  False   False     True  False   False

# %%
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (891,)
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# DecisionTreeClassifier를 생성하는데, 트리의 최대 깊이(depth)를 7로 설정합니다.
# 이렇게 하면 트리의 가지(branch)가 8 depth 아래로 내려가지 않습니다.
# 또한 생성한 DecisionTreeClassifier를 model이라는 이름의 변수에 할당합니다.
model = DecisionTreeClassifier(max_depth=8, random_state=0)
model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
X_test.head()
# Out:
#              Pclass  Sex_encode  Fare_fillin  Embarked_C  Embarked_S  \
# PassengerId
# 892               3         0.0       7.8292       False       False
# 893               3         1.0       7.0000       False        True
# 894               2         0.0       9.6875       False       False
# 895               3         0.0       8.6625       False        True
# 896               3         1.0      12.2875       False        True
#
#              Embarked_Q  Child  Single  Nuclear    Big  Master
# PassengerId
# 892                True  False    True    False  False   False
# 893               False  False   False     True  False   False
# 894                True  False    True    False  False   False
# 895               False  False    True    False  False   False
# 896               False  False   False     True  False   False

# %%
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (891,)
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=8, random_state=0)
model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
import graphviz
from sklearn.tree import export_graphviz
dot_tree = export_graphviz(model, feature_names=feature_names,
                           class_names=["Perish", "Survived"], out_file=None)
graphviz.Source(dot_tree)

# %%
predictions = model.predict(X_test)
print(predictions.shape)
predictions[:10]
# Out:
# (418,)
# array([0, 1, 0, 0, 1, 0, 1, 0, 1, 0])
